# %%
# !pip install ColabTurtlePlus
# Out:
# Collecting ColabTurtlePlus
#   Downloading ColabTurtlePlus-2.0.1-py3-none-any.whl.metadata (10 kB)
# Downloading ColabTurtlePlus-2.0.1-py3-none-any.whl (31 kB)
# Installing collected packages: ColabTurtlePlus
# Successfully installed ColabTurtlePlus-2.0.1

# %%
from ColabTurtlePlus import Turtle
import random
import time

# Function to generate a random pastel color
def random_pastel_color():
    r = int(random.uniform(180, 255))  # Using higher values for a pastel effect
    g = int(random.uniform(180, 255))
    b = int(random.uniform(180, 255))
    return (r, g, b)

# Clearscreen to initialize the drawing area
Turtle.clearscreen()

# Function to display each character with a delay
def display_message(message):
    x_start = -250  # Start position for the message
    y = 250  # Y position above the flowers
    for i, char in enumerate(message):
        Turtle.penup()
        Turtle.goto(x_start + i * 40, y + 10)  # Position each character with a little spacing
        Turtle.pendown()
        Turtle.write(char, font=("Arial", 30, "bold"))  # Display each character in bold
        time.sleep(0.5)  # Pause before showing the next character

# Display the message character by character
display_message("鱼Nero老师教师节快乐🎉🎉!!!")

# Function to draw a single flower with random colors at a given position and a slight tilt
def draw_flower(x, y, tilt_angle):
    Turtle.penup()
    Turtle.goto(x, y)  # Move to the specified (x, y) position
    Turtle.pendown()

    # Set random slight tilt for the flower
    Turtle.setheading(tilt_angle)  # Apply the tilt angle for the flower

    # Flower base
    Turtle.fillcolor(random_pastel_color())
    Turtle.begin_fill()
    Turtle.circle(10, 180)
    Turtle.circle(25, 110)
    Turtle.left(50)
    Turtle.circle(60, 45)
    Turtle.circle(20, 170)
    Turtle.right(24)
    Turtle.forward(30)
    Turtle.left(10)
    Turtle.circle(30, 110)
    Turtle.forward(20)
    Turtle.left(40)
    Turtle.circle(90, 70)
    Turtle.circle(30, 150)
    Turtle.right(30)
    Turtle.forward(15)
    Turtle.circle(80, 90)
    Turtle.left(15)
    Turtle.forward(45)
    Turtle.right(165)
    Turtle.forward(20)
    Turtle.left(155)
    Turtle.circle(150, 80)
    Turtle.left(50)
    Turtle.circle(150, 90)
    Turtle.end_fill()

    # Petal 1
    Turtle.left(150)
    Turtle.circle(-90, 70)
    Turtle.left(20)
    Turtle.circle(75, 105)
    Turtle.setheading(60)
    Turtle.circle(80, 98)
    Turtle.circle(-90, 40)

    # Petal 2
    Turtle.left(180)
    Turtle.circle(90, 40)
    Turtle.circle(-80, 98)
    Turtle.setheading(-83)

    # Leaves 1
    Turtle.forward(30)
    Turtle.left(90)
    Turtle.forward(25)
    Turtle.left(45)
    Turtle.fillcolor("green")
    Turtle.begin_fill()
    Turtle.circle(-80, 90)
    Turtle.right(90)
    Turtle.circle(-80, 90)
    Turtle.end_fill()
    Turtle.right(135)
    Turtle.forward(60)
    Turtle.left(180)
    Turtle.forward(85)
    Turtle.left(90)
    Turtle.forward(80)

    # Leaves 2
    Turtle.right(90)
    Turtle.right(45)
    Turtle.fillcolor("green")
    Turtle.begin_fill()
    Turtle.circle(80, 90)
    Turtle.left(90)
    Turtle.circle(80, 90)
    Turtle.end_fill()
    Turtle.left(135)
    Turtle.forward(60)
    Turtle.left(180)
    Turtle.forward(60)
    Turtle.right(90)
    Turtle.circle(200, 60)

# Draw 10 flowers in different positions on the screen with slight tilt variations
positions = [(-200, 200), (-100, 100), (0, 150), (-300, 220), (100, 170),
             (200,180), (150, 120), (-150, 175), (50, 150), (200, 200)]

for pos in positions:
    tilt_angle = random.uniform(-10, 10)  # Slight tilt variation between -10 and 10 degrees
    draw_flower(pos[0], pos[1], tilt_angle)

# Finish drawing
Turtle.done()
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <text x="150.0" y="40.0" fill="black" text-anchor="start" style="font-size:30px;font-family:'Arial';font-weight:bold;">鱼</text><text x="190.0" y="40.0" fill="black" text-anchor="start" style="font-size:30px;font-family:'Arial';font-weight:bold;">N</text><text x="230.0" y="40.0" fill="black" text-anchor="start" style="font-size:30px;font-family:'Arial';font-weight:bold;">e</text><text x="270.0" y="40.0" fill="black" text-anchor="start" style="font-size:30px;font-family:'Arial';font-weight:bold;">r</text><text x="310.0" y="40.0" fill="black" text-anchor="start" style="font-size:30px;font-family:'Arial';font-weight:bold;">o</text><text x="350.0" y="40.0" fill="black" text-anchor="start" style="font-size:30px;font-family:'Arial';font-weight:bold;">老</text><text x="390.0" y="40.0" fill="black" text-anchor="start" style="font-size:30px;font-family:'Arial';font-weight:bold;">师</text><text x="430.0" y="40.0" fill="black" text-anchor="start" style="font-size:30px;font-family:'Arial';font-weight:bold;">教</text><text x="470.0" y="40.0" fill="black" text-anchor="start" style="font-size:30px;font-family:'Arial';font-weight:bold;">师</text><text x="510.0" y="40.0" fill="black" text-anchor="start" style="font-size:30px;font-family:'Arial';font-weight:bold;">节</text><text x="550.0" y="40.0" fill="black" text-anchor="start" style="font-size:30px;font-family:'Arial';font-weight:bold;">快</text><text x="590.0" y="40.0" fill="black" text-anchor="start" style="font-size:30px;font-family:'Arial';font-weight:bold;">乐</text><text x="630.0" y="40.0" fill="black" text-anchor="start" style="font-size:30px;font-family:'Arial';font-weight:bold;">🎉</text><text x="670.0" y="40.0" fill="black" text-anchor="start" style="font-size:30px;font-family:'Arial';font-weight:bold;">🎉</text><text x="710.0" y="40.0" fill="black" text-anchor="start" style="font-size:30px;font-family:'Arial';font-weight:bold;">!</text><text x="750.0" y="40.0" fill="black" text-anchor="start" style="font-size:30px;font-family:'Arial';font-weight:bold;">!</text><text x="790.0" y="40.0" fill="black" text-anchor="start" style="font-size:30px;font-family:'Arial';font-weight:bold;">!</text><path fill-rule="evenodd" fill-opacity="1" d="M 200.0 100.0  A 10 10 0 0 0 197.951 80.105  A 25 25 0 0 0 178.019 115.885  A 60 60 0 0 0 223.451 109.193  A 20 20 0 0 0 206.058 73.341  L 176.102 71.708  A 30 30 0 0 0 152.937 115.055  L 161.979 132.894  A 90 90 0 0 0 263.012 111.641  A 30 30 0 0 0 232.404 62.427  L 217.796 59.022  A 80 80 0 0 0 121.724 118.774  L 123.2 163.75  L 117.393 144.612  A 150 150 0 0 0 219.237 308.361  A 150 150 0 0 0 267.391 101.767 " stroke-linecap="round" style="stroke:black;stroke-width:1" fill="rgb(197,198,223)" /><path d="M 267.391 101.767 A -90 -90 0 0 1 210.978 188.236" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 210.978 188.236 A 75 75 0 0 0 220.065 306.892" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 220.065 306.892 A 80 80 0 0 0 180.751 192.717" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 180.751 192.717 A -90 -90 0 0 1 135.0 151.523" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 135.0 151.523 A 90 90 0 0 0 180.751 192.717" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 180.751 192.717 A -80 -80 0 0 1 220.065 306.892" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><line x1="220.065" y1="306.892" x2="223.721" y2="336.668" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="223.721" y1="336.668" x2="248.535" y2="333.621" stroke-linecap="round" style="stroke:black;stroke-width:1" /><path fill-rule="evenodd" fill-opacity="1" d="M 248.535 333.621  A -80 -80 0 0 1 360.829 319.833  A -80 -80 0 0 1 248.535 333.621 " stroke-linecap="round" style="stroke:black;stroke-width:1" fill="green" /><line x1="248.535" y1="333.621" x2="308.088" y2="326.309" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="308.088" y1="326.309" x2="223.722" y2="336.668" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="223.722" y1="336.668" x2="233.472" y2="416.072" stroke-linecap="round" style="stroke:black;stroke-width:1" /><path fill-rule="evenodd" fill-opacity="1" d="M 233.472 416.072  A 80 80 0 0 0 121.178 429.86  A 80 80 0 0 0 233.472 416.072 " stroke-linecap="round" style="stroke:black;stroke-width:1" fill="green" /><line x1="233.472" y1="416.072" x2="173.919" y2="423.384" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="173.919" y1="423.384" x2="233.472" y2="416.072" stroke-linecap="round" style="stroke:black;stroke-width:1" /><path d="M 233.472 416.072 A 200 200 0 0 0 353.835 575.799" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path fill-rule="evenodd" fill-opacity="1" d="M 300.0 200.0  A 10 10 0 0 0 299.355 180.01  A 25 25 0 0 0 276.957 214.301  A 60 60 0 0 0 322.747 210.819  A 20 20 0 0 0 307.917 173.833  L 278.15 170.098  A 30 30 0 0 0 251.995 211.71  L 259.761 230.141  A 90 90 0 0 0 362.038 216.042  A 30 30 0 0 0 334.965 164.799  L 320.632 160.376  A 80 80 0 0 0 220.598 213.227  L 218.909 258.195  L 214.461 238.696  A 150 150 0 0 0 304.542 409.199  A 150 150 0 0 0 367.099 206.501 " stroke-linecap="round" style="stroke:black;stroke-width:1" fill="rgb(240,184,208)" /><path d="M 367.099 206.501 A -90 -90 0 0 1 304.748 288.791" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 304.748 288.791 A 75 75 0 0 0 305.472 407.792" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 305.472 407.792 A 80 80 0 0 0 266.158 293.617" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M
" stroke-linecap="round" style="stroke:black;stroke-width:1" fill="rgb(240,184,208)" /><path d="M 367.099 206.501 A -90 -90 0 0 1 304.748 288.791" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 304.748 288.791 A 75 75 0 0 0 305.472 407.792" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 305.472 407.792 A 80 80 0 0 0 266.158 293.617" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 266.158 293.617 A -90 -90 0 0 1 220.407 252.423" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 220.407 252.423 A 90 90 0 0 0 266.158 293.617" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 266.158 293.617 A -80 -80 0 0 1 305.472 407.792" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><line x1="305.472" y1="407.792" x2="309.128" y2="437.568" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="309.128" y1="437.568" x2="333.942" y2="434.521" stroke-linecap="round" style="stroke:black;stroke-width:1" /><path fill-rule="evenodd" fill-opacity="1" d="M 333.942 434.521  A -80 -80 0 0 1 446.236 420.733  A -80 -80 0 0 1 333.942 434.521 " stroke-linecap="round" style="stroke:black;stroke-width:1" fill="green" /><line x1="333.942" y1="434.521" x2="393.495" y2="427.209" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="393.495" y1="427.209" x2="309.129" y2="437.568" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="309.129" y1="437.568" x2="318.879" y2="516.972" stroke-linecap="round" style="stroke:black;stroke-width:1" /><path fill-rule="evenodd" fill-opacity="1" d="M 318.879 516.972  A 80 80 0 0 0 206.585 530.76  A 80 80 0 0 0 318.879 516.972 " stroke-linecap="round" style="stroke:black;stroke-width:1" fill="green" /><line x1="318.879" y1="516.972" x2="259.326" y2="524.284" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="259.326" y1="524.284" x2="318.879" y2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-43a92e7a63c7> in <cell line: 120>()
#     120 for pos in positions:
#     121     tilt_angle = random.uniform(-10, 10)  # Slight tilt variation between -10 and 10 degrees
# --> 122     draw_flower(pos[0], pos[1], tilt_angle)
#     123
#     124 # Finish drawing
#
# <ipython-input-5-43a92e7a63c7> in draw_flower(x, y, tilt_angle)
#      58     Turtle.forward(45)
#      59     Turtle.right(165)
# ---> 60     Turtle.forward(20)
#      61     Turtle.left(155)
#      62     Turtle.circle(150, 80)
#
# /usr/local/lib/python3.10/dist-packages/ColabTurtlePlus/Turtle.py in forward(units)
#
# /usr/local/lib/python3.10/dist-packages/ColabTurtlePlus/Turtle.py in forward(self, units)
#     860         alpha = math.radians(self.turtle_degree)
#     861         new_pos = (self.turtle_pos[0] + units * self.screen.xscale * math.cos(alpha), self.turtle_pos[1] + units * abs(self.screen.yscale) * math.sin(alpha))
# --> 862         self.screen._moveToNewPosition(new_pos,units, turtle=self)
#     863     fd = forward # alias
#     864
#
# /usr/local/lib/python3.10/dist-packages/ColabTurtlePlus/Turtle.py in _moveToNewPosition(self, new_pos, units, turtle)
#     362                             pwidth=turtle.pen_width)
#     363                     initial_pos = turtle.turtle_pos
# --> 364                     self._updateDrawing(turtle=turtle)
#     365                     units -= dunits
#     366             else:
#
# /usr/local/lib/python3.10/dist-packages/ColabTurtlePlus/Turtle.py in _updateDrawing(self, turtle, delay)
#     325                 self.drawing_window.update(HTML(self._generateSvgDrawing()))
#     326                 if delay:
# --> 327                     time.sleep(turtle.timeout)
#     328         else:
#     329             self.drawing_window.update(HTML(self._generateSvgDrawing()))
#
# KeyboardInterrupt:
